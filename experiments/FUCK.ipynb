# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\evgen\Desktop\MIRAGE\env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\evgen\Desktop\MIRAGE\env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\evgen\Desktop\MIRAGE\env\Lib\site-packages)

# %%
import sys
sys.path.append('..')
import mirage
index = mirage.MirageIndex.load("E:\indexes1\S_2_0.1_BAAI_ip.mirage_index")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\i'
# <>:4: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\evgen\AppData\Local\Temp\ipykernel_13556\296738471.py:4: SyntaxWarning: invalid escape sequence '\i'
#   index = mirage.MirageIndex.load("E:\indexes1\S_2_0.1_BAAI_ip.mirage_index")

# %%
set(a)
# Out:
# {'Приказ Росавиации от 28.12.2022 N 970-П  Об утверждении Норм.txt',
#  'Приказ_Минтранса_РФ_от_21_11_2005_N_139_ред_от_17_09_2010.rtf.txt',
#  'ФАП-10.txt',
#  'ФАП-109.txt',
#  'ФАП-128.txt',
#  'ФАП-138.txt',
#  'ФАП-139.txt',
#  'ФАП-141.txt',
#  'ФАП-147 АОН.txt',
#  'ФАП-147.txt',
#  'ФАП-273.txt',
#  'ФАП-29.txt',
#  'ФАП-293.txt',
#  'ФАП-32.txt',
#  'ФАП-437.txt',
#  'ФАП-519.txt',
#  'ФАП-82.txt'}

# %%
from tqdm import tqdm


a = [ chunk for chunk in tqdm(index.chunk_storage) if index.chunk_storage.get_raw_index_of_document(chunk[0]) == 'Приказ Росавиации от 28.12.2022 N 970-П  Об утверждении Норм.txt' ]
# Out:
# 0it [00:00, ?it/s]
# 3882it [00:15, 257.02it/s]

# %%
a
# Out:
# [('d3f65bd5-be6c-46ce-81ab-3cb6d028c4e2',
# ...
